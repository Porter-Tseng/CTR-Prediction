# %% [markdown]
# ## <span style="color:grey; font-weight:bold;">Import Tools and Def Functions</span>

# %%
import pandas as pd
import os
import missingno as msno

# %%
from Def_Function import RenameandCheckDuplicateandNaN, ColumnsNaNSorted, RemovedColumnOver50, SeparateNumericalandObjective
from Def_Function import ColumnsHist, CorrHeatMap, CountStatistic, ImputeNaN, ObjectiveLabelEncoder, NaNColumns, MergeAllTypeofColumns
from Def_Function import FilterColumns, DropSpecificRowNaN, ModelFillNaN, CheckNegativeColumns, SkewCountingandTransformWithoutHist
from Def_Function import BoxPlot, IQRRemoveOutlier, ExtremeRemoveOutlier, SaveCSV

# %%
from Def_Function import NumericalFunctionPackage, ObjectiveFunctionPackage, SkewandRemoveOutlier

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data_path = '/home/ctr-prediction/Porter - Project/05 - Advertising Challenge - Data Analysis/Data'
os.chdir(data_path)

files = os.listdir()
print(files)

# %% [markdown]
# ## <span style="color:skyblue; font-weight:bold;">Train Chunk 3</span>

# %%
numerical_chunk3, objective_chunk3 = NumericalFunctionPackage(
    'Base Train DataFrame Chunk3.csv',
    '3'
)

# %%
df_chunk3 = ObjectiveFunctionPackage(
    objective_chunk3,
    numerical_chunk3,
    '19',
    '3'
)

# %%
removeoutlier_df_chunk3 = SkewandRemoveOutlier(
    df_chunk3,
    '3',
)

# %% [markdown]
# ## <span style="color:skyblue; font-weight:bold;">Train Chunk 4</span>

# %%
numerical_chunk4, objective_chunk4 = NumericalFunctionPackage(
    'Base Train DataFrame Chunk4.csv',
    '4'
)

# %%
df_chunk4 = ObjectiveFunctionPackage(
    objective_chunk4,
    numerical_chunk4,
    '19',
    '4'
)

# %%
removeoutlier_df_chunk4 = SkewandRemoveOutlier(
    df_chunk4,
    '4',
)

# %% [markdown]
# ## <span style="color:skyblue; font-weight:bold;">Train Chunk 5</span>

# %%
numerical_chunk5, objective_chunk5 = NumericalFunctionPackage(
    'Base Train DataFrame Chunk5.csv',
    '5'
)

# %%
df_chunk5 = ObjectiveFunctionPackage(
    objective_chunk5,
    numerical_chunk5,
    '19',
    '5'
)

# %%
removeoutlier_df_chunk5 = SkewandRemoveOutlier(
    df_chunk5,
    '5',
)
